# %% [markdown]
# # Car Price Prediction using Feedforward Neural Network
# This notebook demonstrates the process of building a Feedforward Neural Network (FNN) to predict car prices using the provided dataset. We will go through data loading, cleaning, preprocessing, model building, training, evaluation, and prediction.

# %% [markdown]
# ## Data Loading
# We begin by loading the dataset using pandas.

# %%
import pandas as pd

df = pd.read_csv("CarPrice_dataset.csv")
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Data Cleaning
# We check for missing values and drop unnecessary columns if any.

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# ## Data Preprocessing
# We handle categorical variables using one-hot encoding and normalize numerical features.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

# Separate features and target
X = df.drop(columns=['price'])
y = df['price']

# Identify categorical and numerical columns
categorical_cols = X.select_dtypes(include=['object']).columns.tolist()
numerical_cols = X.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Define preprocessing steps
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_cols),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols)
    ])

# Apply preprocessing
X_processed = preprocessor.fit_transform(X)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_processed, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Model Building
# We build a Feedforward Neural Network using TensorFlow/Keras.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Define the model
model = Sequential([
    Dense(512, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mean_absolute_error', metrics = ["mean_absolute_error", "mean_squared_error"])
model.summary()
# Out:
# c:\Users\bhawa\miniconda3\envs\dataScience\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_43 (Dense)                │ (None, 512)            │       102,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_44 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_45 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_46 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_47 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_48 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 277,505 (1.06 MB)
#  Trainable params: 277,505 (1.06 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Model Training
# We train the model using the training data.

# %%
history = model.fit(X_train, y_train, epochs=70, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 12410.6309 - mean_absolute_error: 12410.6309 - mean_squared_error: 195753200.0000 - val_loss: 15080.3799 - val_mean_absolute_error: 15080.3799 - val_mean_squared_error: 317852800.0000
# Epoch 2/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 12204.8818 - mean_absolute_error: 12204.8818 - mean_squared_error: 191640992.0000 - val_loss: 15072.0039 - val_mean_absolute_error: 15072.0039 - val_mean_squared_error: 317581440.0000
# Epoch 3/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 12901.4805 - mean_absolute_error: 12901.4805 - mean_squared_error: 217842960.0000 - val_loss: 15046.7939 - val_mean_absolute_error: 15046.7939 - val_mean_squared_error: 316785632.0000
# Epoch 4/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 12664.7217 - mean_absolute_error: 12664.7217 - mean_squared_error: 212468112.0000 - val_loss: 14979.7051 - val_mean_absolute_error: 14979.7051 - val_mean_squared_error: 314703328.0000
# Epoch 5/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 12857.4600 - mean_absolute_error: 12857.4600 - mean_squared_error: 219988560.0000 - val_loss: 14816.6973 - val_mean_absolute_error: 14816.6973 - val_mean_squared_error: 309752064.0000
# Epoch 6/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 12695.8818 - mean_absolute_error: 12695.8818 - mean_squared_error: 217070400.0000 - val_loss: 14452.1895 - val_mean_absolute_error: 14452.1895 - val_mean_squared_error: 298902080.0000
# Epoch 7/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 11793.6826 - mean_absolute_error: 11793.6826 - mean_squared_error: 188557568.0000 - val_loss: 13689.8301 - val_mean_absolute_error: 13689.8301 - val_mean_squared_error: 277227008.0000
# Epoch 8/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 11056.6455 - mean_absolute_error: 11056.6455 - mean_squared_error: 172899248.0000 - val_loss: 12174.0244 - val_mean_absolute_error: 12174.0244 - val_mean_squared_error: 237361088.0000
# Epoch 9/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 9367.8750 - mean_absolute_error: 9367.8750 - mean_squared_error: 143573776.0000 - val_loss: 9408.1533 - val_mean_absolute_error: 9408.1533 - val_mean_squared_error: 176358192.0000
# Epoch 10/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 6286.6572 - mean_absolute_error: 6286.6572 - mean_squared_error: 82398632.0000 - val_loss: 6897.1313 - val_mean_absolute_error: 6897.1313 - val_mean_squared_error: 107122048.0000
# Epoch 11/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 5060.1304 - mean_absolute_error: 5060.1304 - mean_squared_error: 58784128.0000 - val_loss: 5380.4731 - val_mean_absolute_error: 5380.4731 - val_mean_squared_error: 63789476.0000
# Epoch 12/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 3945.6682 - mean_absolute_error: 3945.6682 - mean_squared_error: 29190336.0000 - val_loss: 4034.0203 - val_mean_absolute_error: 4034.0203 - val_mean_squared_error: 36387200.0000
# Epoch 13/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 3104.5674 - mean_absolute_error: 3104.5674 - mean_squared_error: 21017584.0000 - val_loss: 3210.1785 - val_mean_absolute_error: 3210.1785 - val_mean_squared_error: 31162434.0000
# Epoch 14/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 2417.6199 - mean_absolute_error: 2417.6199 - mean_squared_error: 19804972.0000 - val_loss: 2963.0725 - val_mean_absolute_error: 2963.0725 - val_mean_squared_error: 22884878.0000
# Epoch 15/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 2252.6299 - mean_absolute_error: 2252.6299 - mean_squared_error: 15480936.0000 - val_loss: 2562.2112 - val_mean_absolute_error: 2562.2112 - val_mean_squared_error: 14330393.0000
# Epoch 16/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 2129.3232 - mean_absolute_error: 2129.3232 - mean_squared_error: 11020910.0000 - val_loss: 2586.6707 - val_mean_absolute_error: 2586.6707 - val_mean_squared_error: 15508614.0000
# Epoch 17/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1975.3718 - mean_absolute_error: 1975.3718 - mean_squared_error: 10701876.0000 - val_loss: 3046.0203 - val_mean_absolute_error: 3046.0203 - val_mean_squared_error: 21772610.0000
# Epoch 18/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1695.7512 - mean_absolute_error: 1695.7512 - mean_squared_error: 9125034.0000 - val_loss: 2523.0527 - val_mean_absolute_error: 2523.0527 - val_mean_squared_error: 16512613.0000
# Epoch 19/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1836.0242 - mean_absolute_error: 1836.0242 - mean_squared_error: 8586702.0000 - val_loss: 2486.1538 - val_mean_absolute_error: 2486.1538 - val_mean_squared_error: 15543765.0000
# Epoch 20/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1687.5419 - mean_absolute_error: 1687.5419 - mean_squared_error: 8785795.0000 - val_loss: 2975.9910 - val_mean_absolute_error: 2975.9910 - val_mean_squared_error: 22014980.0000
# Epoch 21/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1723.2266 - mean_absolute_error: 1723.2266 - mean_squared_error: 9823554.0000 - val_loss: 2920.1165 - val_mean_absolute_error: 2920.1165 - val_mean_squared_error: 21884970.0000
# Epoch 22/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1580.8857 - mean_absolute_error: 1580.8857 - mean_squared_error: 7337750.0000 - val_loss: 2363.4863 - val_mean_absolute_error: 2363.4863 - val_mean_squared_error: 13466778.0000
# Epoch 23/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 1733.6658 - mean_absolute_error: 1733.6658 - mean_squared_error: 7925279.0000 - val_loss: 2322.7236 - val_mean_absolute_error: 2322.7236 - val_mean_squared_error: 12705684.0000
# Epoch 24/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 1575.1838 - mean_absolute_error: 1575.1838 - mean_squared_error: 7303794.5000 - val_loss: 2756.6184 - val_mean_absolute_error: 2756.6184 - val_mean_squared_error: 17790258.0000
# Epoch 25/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 1343.8868 - mean_absolute_error: 1343.8868 - mean_squared_error: 5232845.0000 - val_loss: 2441.0527 - val_mean_absolute_error: 2441.0527 - val_mean_squared_error: 14050415.0000
# Epoch 26/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 1449.4032 - mean_absolute_error: 1449.4032 - mean_squared_error: 7136527.5000 - val_loss: 2476.8918 - val_mean_absolute_error: 2476.8918 - val_mean_squared_error: 14466639.0000
# Epoch 27/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 1229.5498 - mean_absolute_error: 1229.5498 - mean_squared_error: 5539418.0000 - val_loss: 2524.9668 - val_mean_absolute_error: 2524.9668 - val_mean_squared_error: 15143205.0000
# Epoch 28/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 1129.0625 - mean_absolute_error: 1129.0625 - mean_squared_error: 4300080.5000 - val_loss: 2346.8689 - val_mean_absolute_error: 2346.8689 - val_mean_squared_error: 12271039.0000
# Epoch 29/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1196.1034 - mean_absolute_error: 1196.1034 - mean_squared_error: 4722256.0000 - val_loss: 2494.1277 - val_mean_absolute_error: 2494.1277 - val_mean_squared_error: 14156053.0000
# Epoch 30/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1261.9067 - mean_absolute_error: 1261.9067 - mean_squared_error: 5943004.5000 - val_loss: 2414.2908 - val_mean_absolute_error: 2414.2908 - val_mean_squared_error: 12894864.0000
# Epoch 31/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1177.5026 - mean_absolute_error: 1177.5026 - mean_squared_error: 4189999.7500 - val_loss: 2283.0781 - val_mean_absolute_error: 2283.0781 - val_mean_squared_error: 11280197.0000
# Epoch 32/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1021.7308 - mean_absolute_error: 1021.7308 - mean_squared_error: 2951429.5000 - val_loss: 2413.2476 - val_mean_absolute_error: 2413.2476 - val_mean_squared_error: 12948876.0000
# Epoch 33/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 926.8253 - mean_absolute_error: 926.8253 - mean_squared_error: 3249755.0000 - val_loss: 2361.8071 - val_mean_absolute_error: 2361.8071 - val_mean_squared_error: 12399080.0000
# Epoch 34/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 1125.8519 - mean_absolute_error: 1125.8519 - mean_squared_error: 3913761.0000 - val_loss: 2484.5891 - val_mean_absolute_error: 2484.5891 - val_mean_squared_error: 13954897.0000
# Epoch 35/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 1165.3906 - mean_absolute_error: 1165.3906 - mean_squared_error: 4427666.0000 - val_loss: 2477.6335 - val_mean_absolute_error: 2477.6335 - val_mean_squared_error: 13864502.0000
# Epoch 36/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 942.5551 - mean_absolute_error: 942.5551 - mean_squared_error: 3135312.7500 - val_loss: 2221.8831 - val_mean_absolute_error: 2221.8831 - val_mean_squared_error: 10812333.0000
# Epoch 37/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 953.0094 - mean_absolute_error: 953.0094 - mean_squared_error: 2588450.7500 - val_loss: 2319.9668 - val_mean_absolute_error: 2319.9668 - val_mean_squared_error: 11711768.0000
# Epoch 38/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 875.5554 - mean_absolute_error: 875.5554 - mean_squared_error: 2431047.5000 - val_loss: 2197.0625 - val_mean_absolute_error: 2197.0625 - val_mean_squared_error: 10646127.0000
# Epoch 39/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 829.1067 - mean_absolute_error: 829.1067 - mean_squared_error: 2010052.8750 - val_loss: 2406.6987 - val_mean_absolute_error: 2406.6987 - val_mean_squared_error: 13097261.0000
# Epoch 40/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 892.5435 - mean_absolute_error: 892.5435 - mean_squared_error: 2548802.0000 - val_loss: 2306.6504 - val_mean_absolute_error: 2306.6504 - val_mean_squared_error: 11894191.0000
# Epoch 41/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 776.6599 - mean_absolute_error: 776.6599 - mean_squared_error: 1828096.7500 - val_loss: 2312.0649 - val_mean_absolute_error: 2312.0649 - val_mean_squared_error: 11874213.0000
# Epoch 42/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 806.9289 - mean_absolute_error: 806.9289 - mean_squared_error: 1935717.5000 - val_loss: 2142.3086 - val_mean_absolute_error: 2142.3086 - val_mean_squared_error: 9979968.0000
# Epoch 43/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 866.1600 - mean_absolute_error: 866.1600 - mean_squared_error: 1610861.5000 - val_loss: 2171.7627 - val_mean_absolute_error: 2171.7627 - val_mean_squared_error: 10178817.0000
# Epoch 44/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 839.1072 - mean_absolute_error: 839.1072 - mean_squared_error: 1756709.7500 - val_loss: 2136.3552 - val_mean_absolute_error: 2136.3552 - val_mean_squared_error: 10213589.0000
# Epoch 45/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 748.0793 - mean_absolute_error: 748.0793 - mean_squared_error: 1330359.5000 - val_loss: 2278.6548 - val_mean_absolute_error: 2278.6548 - val_mean_squared_error: 11819807.0000
# Epoch 46/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 764.6555 - mean_absolute_error: 764.6555 - mean_squared_error: 1515265.7500 - val_loss: 2215.9614 - val_mean_absolute_error: 2215.9614 - val_mean_squared_error: 11084869.0000
# Epoch 47/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 656.8781 - mean_absolute_error: 656.8781 - mean_squared_error: 1185089.6250 - val_loss: 2152.5254 - val_mean_absolute_error: 2152.5254 - val_mean_squared_error: 10044296.0000
# Epoch 48/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 627.4082 - mean_absolute_error: 627.4082 - mean_squared_error: 1030119.3125 - val_loss: 2173.3801 - val_mean_absolute_error: 2173.3801 - val_mean_squared_error: 10234494.0000
# Epoch 49/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 579.3603 - mean_absolute_error: 579.3603 - mean_squared_error: 878674.8750 - val_loss: 2229.3074 - val_mean_absolute_error: 2229.3074 - val_mean_squared_error: 11105834.0000
# Epoch 50/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 591.5812 - mean_absolute_error: 591.5812 - mean_squared_error: 943684.6875 - val_loss: 2124.9990 - val_mean_absolute_error: 2124.9990 - val_mean_squared_error: 9556482.0000
# Epoch 51/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 675.6194 - mean_absolute_error: 675.6194 - mean_squared_error: 1034476.1875 - val_loss: 2166.2815 - val_mean_absolute_error: 2166.2815 - val_mean_squared_error: 9706756.0000
# Epoch 52/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 558.4629 - mean_absolute_error: 558.4629 - mean_squared_error: 741046.5000 - val_loss: 2165.3770 - val_mean_absolute_error: 2165.3770 - val_mean_squared_error: 9831644.0000
# Epoch 53/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 455.1304 - mean_absolute_error: 455.1304 - mean_squared_error: 589552.0000 - val_loss: 2260.4768 - val_mean_absolute_error: 2260.4768 - val_mean_squared_error: 10971440.0000
# Epoch 54/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 491.8937 - mean_absolute_error: 491.8937 - mean_squared_error: 613203.3125 - val_loss: 2138.3848 - val_mean_absolute_error: 2138.3848 - val_mean_squared_error: 9521978.0000
# Epoch 55/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 514.5405 - mean_absolute_error: 514.5405 - mean_squared_error: 664449.8750 - val_loss: 2106.8945 - val_mean_absolute_error: 2106.8945 - val_mean_squared_error: 9151544.0000
# Epoch 56/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 531.0509 - mean_absolute_error: 531.0509 - mean_squared_error: 679455.3125 - val_loss: 2109.2180 - val_mean_absolute_error: 2109.2180 - val_mean_squared_error: 9274175.0000
# Epoch 57/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 475.9543 - mean_absolute_error: 475.9543 - mean_squared_error: 573346.1250 - val_loss: 2198.8450 - val_mean_absolute_error: 2198.8450 - val_mean_squared_error: 10383492.0000
# Epoch 58/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 523.7064 - mean_absolute_error: 523.7064 - mean_squared_error: 594612.6250 - val_loss: 2171.4333 - val_mean_absolute_error: 2171.4333 - val_mean_squared_error: 9517756.0000
# Epoch 59/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 438.2094 - mean_absolute_error: 438.2094 - mean_squared_error: 483701.8750 - val_loss: 2138.2908 - val_mean_absolute_error: 2138.2908 - val_mean_squared_error: 8738596.0000
# Epoch 60/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 416.4952 - mean_absolute_error: 416.4952 - mean_squared_error: 483987.2500 - val_loss: 2223.2585 - val_mean_absolute_error: 2223.2585 - val_mean_squared_error: 9930582.0000
# Epoch 61/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 391.6805 - mean_absolute_error: 391.6805 - mean_squared_error: 464087.3750 - val_loss: 2228.3938 - val_mean_absolute_error: 2228.3938 - val_mean_squared_error: 10150875.0000
# Epoch 62/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 461.9188 - mean_absolute_error: 461.9188 - mean_squared_error: 501046.8125 - val_loss: 2145.1448 - val_mean_absolute_error: 2145.1448 - val_mean_squared_error: 9070762.0000
# Epoch 63/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 535.1161 - mean_absolute_error: 535.1161 - mean_squared_error: 580864.2500 - val_loss: 2196.4131 - val_mean_absolute_error: 2196.4131 - val_mean_squared_error: 10607498.0000
# Epoch 64/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 432.1220 - mean_absolute_error: 432.1220 - mean_squared_error: 419740.6875 - val_loss: 2112.5281 - val_mean_absolute_error: 2112.5281 - val_mean_squared_error: 9121304.0000
# Epoch 65/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 412.7274 - mean_absolute_error: 412.7274 - mean_squared_error: 431595.5000 - val_loss: 2133.0222 - val_mean_absolute_error: 2133.0222 - val_mean_squared_error: 9089949.0000
# Epoch 66/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 400.4373 - mean_absolute_error: 400.4373 - mean_squared_error: 477007.2500 - val_loss: 2184.3284 - val_mean_absolute_error: 2184.3284 - val_mean_squared_error: 9834109.0000
# Epoch 67/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 332.7604 - mean_absolute_error: 332.7604 - mean_squared_error: 328957.1875 - val_loss: 2158.1755 - val_mean_absolute_error: 2158.1755 - val_mean_squared_error: 9176596.0000
# Epoch 68/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 328.4680 - mean_absolute_error: 328.4680 - mean_squared_error: 302485.6250 - val_loss: 2163.3674 - val_mean_absolute_error: 2163.3674 - val_mean_squared_error: 9300563.0000
# Epoch 69/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 332.6216 - mean_absolute_error: 332.6216 - mean_squared_error: 302248.6875 - val_loss: 2173.5232 - val_mean_absolute_error: 2173.5232 - val_mean_squared_error: 9608176.0000
# Epoch 70/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 381.9026 - mean_absolute_error: 381.9026 - mean_squared_error: 351465.7500 - val_loss: 2201.3811 - val_mean_absolute_error: 2201.3811 - val_mean_squared_error: 10319916.0000

# %% [markdown]
# ## Model Evaluation
# We evaluate the model using the test data.

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score

y_pred = model.predict(X_test)

# Calculate metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}")
print(f"R-squared Score: {r2}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Mean Absolute Error: 1924.6534872332318
# Mean Squared Error: 9683699.13864835
# R-squared Score: 0.8773346096291423

# %% [markdown]
# ## Prediction on New Data
# We demonstrate prediction using new sample data.

# %%
# Example new data (replace with actual values from dataset)
new_data = X.iloc[[0]]
new_data_processed = preprocessor.transform(new_data)

predicted_price = model.predict(new_data_processed)
print(f"Predicted Price: {predicted_price[0][0]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Predicted Price: 13592.580078125
